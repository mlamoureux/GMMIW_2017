# %% [markdown]
# ## YouTube videos
#
# With just a few lines, you can include YouTube videos in your Notebook.
#
# You do need to be connected to the internet.

# %%
from IPython.display import YouTubeVideo
# Navjo Math Circles - Tatiana Shubin
YouTubeVideo('nrNV7oVK_Eg')
